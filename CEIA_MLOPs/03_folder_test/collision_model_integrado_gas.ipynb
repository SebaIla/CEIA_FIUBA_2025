# %% [markdown]
# # 🧩 Integración de tus módulos en el pipeline (Metaflow + MLflow)
#
# Este notebook usa **tus archivos** (`data_ingestion.py`, `data_preprocessing.py`, `train.py`, `collision_flow.py`) dentro de la estructura del proyecto.
# Podés correr **paso a paso** (ingesta → preprocesamiento → entrenamiento) o lanzar el **flujo completo de Metaflow**.

# %% [markdown]
# ## 0) Verificación de estructura y dependencias

# %%
from pathlib import Path
BASE = Path(r"collision-model-project")
for p in [BASE/'src', BASE/'flows', BASE/'data'/'raw', BASE/'data'/'processed', BASE/'mlruns']:
    p.mkdir(parents=True, exist_ok=True)

print("Base:", BASE)
print("Contenido de src/:", list((BASE/'src').iterdir()))
print("Contenido de flows/:", list((BASE/'flows').iterdir()))
# Out:
# Base: collision-model-project
# Contenido de src/: [WindowsPath('collision-model-project/src/data_ingestion.py'), WindowsPath('collision-model-project/src/data_preprocessing.py'), WindowsPath('collision-model-project/src/train.py'), WindowsPath('collision-model-project/src/__init__.py')]
# Contenido de flows/: [WindowsPath('collision-model-project/flows/collision_flow.py')]

# %% [markdown]
# ## 1) Ingesta con tu módulo (`src/data_ingestion.py`)
#
# Esta celda importa y ejecuta `ingest_collision_data()` para descargar y guardar datos crudos en `data/raw/la_collisions_raw.csv`.

# %%
from importlib import reload
import sys
sys.path.append(str(BASE))

from src import data_ingestion
reload(data_ingestion)

df_raw = data_ingestion.ingest_collision_data()
print(df_raw.shape)
df_raw.head()
# Out:
# Starting data retrieval...
# ✅ Partially ingested 50000 rows (Total: 50000)
# ✅ Partially ingested 50000 rows (Total: 100000)
# ✅ Partially ingested 50000 rows (Total: 150000)
# ✅ Partially ingested 50000 rows (Total: 200000)
# ✅ Partially ingested 50000 rows (Total: 250000)
# ✅ Partially ingested 50000 rows (Total: 300000)
# ✅ Partially ingested 50000 rows (Total: 350000)
# ✅ Partially ingested 50000 rows (Total: 400000)
# ✅ Partially ingested 50000 rows (Total: 450000)
# ✅ Partially ingested 50000 rows (Total: 500000)
# ✅ Partially ingested 50000 rows (Total: 550000)
# ✅ Partially ingested 50000 rows (Total: 600000)
# ✅ Partially ingested 21677 rows (Total: 621677)
# (621677, 26)
#        dr_no                date_rptd                 date_occ time_occ area  \
# 0  212013850  2021-09-03T00:00:00.000  2021-09-02T00:00:00.000     2335   20
# 1  221417787  2022-10-17T00:00:00.000  2022-10-17T00:00:00.000     1620   14
# 2  221418141  2022-10-26T00:00:00.000  2022-10-26T00:00:00.000     1135   14
# 3  222017859  2022-12-01T00:00:00.000  2022-12-01T00:00:00.000     0230   20
# 4  190319651  2019-08-24T00:00:00.000  2019-08-24T00:00:00.000     0450   03
#
#    area_name rpt_dist_no crm_cd        crm_cd_desc  \
# 0    Olympic        2021    997  TRAFFIC COLLISION
# 1    Pacific        1406    997  TRAFFIC COLLISION
# 2    Pacific        1434    997  TRAFFIC COLLISION
# 3    Olympic        2044    997  TRAFFIC COLLISION
# 4  Southwest        0356    997  TRAFFIC COLLISION
#
#                                         mocodes  ...  \
# 0       3004 3027 3034 4027 3036 3101 3401 3701  ...
# 1       4027 3011 3028 3034 3037 3101 3401 3701  ...
# 2       4027 3011 3025 3034 3037 3101 3401 3701  ...
# 3  3003 0913 3026 3035 3037 3101 3401 3701 4020  ...
# 4                      3036 3004 3026 3101 4003  ...
#
#                       cross_street :@computed_region_qz3q_ghft  \
# 0  6TH                          ST                       22722
# 1  MOTOR                        AV                       23451
# 2  ROSEWOOD                     AV                       24031
# 3  SAN MARINO                   ST                       22723
# 4  NORMANDIE                    AV                       22724
#
#   :@computed_region_k96s_3jcv :@computed_region_tatf_ua23  \
# 0                         588                         875
# 1                         881                        1358
# 2                         891                         855
# 3                         607                         647
# 4                         691                         916
#
#   :@computed_region_ur2y_g4cx :@computed_region_kqwf_mjcx  \
# 0                          36                           7
# 1                           9                           6
# 2                          10                          10
# 3                         NaN                          12
# 4                           7                          14
#
#   :@computed_region_2dna_qi2s location_1.latitude location_1.longitude  \
# 0                          86              34.063            -118.3141
# 1                          74              34.029            -118.4113
# 2                          27             34.0052            -118.4478
# 3                          89             34.0545            -118.3009
# 4                          32             34.0255            -118.3002
#
#                             location_1.human_address
# 0  {"address": "", "city": "", "state": "", "zip"...
# 1  {"address": "", "city": "", "state": "", "zip"...
# 2  {"address": "", "city": "", "state": "", "zip"...
# 3  {"address": "", "city": "", "state": "", "zip"...
# 4  {"address": "", "city": "", "state": "", "zip"...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 2) Preprocesamiento con tu módulo (`src/data_preprocessing.py`)
#
# Toma el DataFrame crudo y genera `data/processed/processed_data.csv` con las features temporales (lags, rolling, etc.).

# %%
from src import data_preprocessing
reload(data_preprocessing)

df_processed = data_preprocessing.preprocess_data(df_raw)
print(df_processed.shape)
df_processed.head()
# Out:
# (5271, 8)
#     date_occ  collision_count  dayofyear  weekday  year  lag_1  lag_2  \
# 0 2010-01-03               11          3        6  2010    5.0    9.0
# 1 2010-01-04                7          4        0  2010   11.0    5.0
# 2 2010-01-05                3          5        1  2010    7.0   11.0
# 3 2010-01-06                5          6        2  2010    3.0    7.0
# 4 2010-01-08                7          8        4  2010    5.0    3.0
#
#    rolling_mean_3
# 0        8.333333
# 1        7.666667
# 2        7.000000
# 3        5.000000
# 4        5.000000

# %% [markdown]
# ## 3) Entrenamiento + MLflow con tu módulo (`src/train.py`)
#
# Entrena un **RandomForestRegressor** y registra métricas/artefactos en **MLflow** (experimento `Collision_Prediction`).
# La ruta de tracking se configura localmente en `mlruns/`.

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error, r2_score

# 📦 pandas
import pandas as pd

# 📦 numpy
import numpy as np

# 📦 matplotlib
import matplotlib.pyplot as plt

# %%
# !pip install mlflow metaflow
# Out:
# Requirement already satisfied: mlflow in d:\users\user\anaconda3\lib\site-packages (3.3.1)
# Requirement already satisfied: metaflow in d:\users\user\anaconda3\lib\site-packages (2.17.3)
# Requirement already satisfied: mlflow-skinny==3.3.1 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (3.3.1)
# Requirement already satisfied: mlflow-tracing==3.3.1 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (3.3.1)
# Requirement already satisfied: Flask<4 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (2.2.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (1.16.4)
# Requirement already satisfied: cryptography<46,>=43.0.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (45.0.6)
# Requirement already satisfied: docker<8,>=4.0.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: matplotlib<4 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (3.8.0)
# Requirement already satisfied: numpy<3 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (2.1.4)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (14.0.2)
# Requirement already satisfied: scikit-learn<2 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: scipy<2 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (1.11.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (2.0.25)
# Requirement already satisfied: waitress<4 in d:\users\user\anaconda3\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (2.2.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (0.64.0)
# Requirement already satisfied: fastapi<1 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (3.1.37)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (7.0.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (1.36.0)
# Requirement already satisfied: packaging<26 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (23.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (3.20.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (2.10.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (4.12.2)
# Requirement already satisfied: uvicorn<1 in d:\users\user\anaconda3\lib\site-packages (from mlflow-skinny==3.3.1->mlflow) (0.35.0)
# Requirement already satisfied: boto3 in d:\users\user\anaconda3\lib\site-packages (from metaflow) (1.40.16)
# Requirement already satisfied: Mako in d:\users\user\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.14 in d:\users\user\anaconda3\lib\site-packages (from cryptography<46,>=43.0.0->mlflow) (1.16.0)
# Requirement already satisfied: pywin32>=304 in d:\users\user\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: urllib3>=1.26.0 in d:\users\user\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.0.7)
# Requirement already satisfied: Werkzeug>=2.2.2 in d:\users\user\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in d:\users\user\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in d:\users\user\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in d:\users\user\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in d:\users\user\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in d:\users\user\anaconda3\lib\site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\user\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\users\user\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\user\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\users\user\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in d:\users\user\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\users\user\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in d:\users\user\anaconda3\lib\site-packages (from pandas<3->mlflow) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\users\user\anaconda3\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.1->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.1->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.1->mlflow) (2025.1.31)
# Requirement already satisfied: joblib>=1.1.1 in d:\users\user\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\user\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\users\user\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.1)
# Requirement already satisfied: botocore<1.41.0,>=1.40.16 in d:\users\user\anaconda3\lib\site-packages (from boto3->metaflow) (1.40.16)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\users\user\anaconda3\lib\site-packages (from boto3->metaflow) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in d:\users\user\anaconda3\lib\site-packages (from boto3->metaflow) (0.13.1)
# Requirement already satisfied: pycparser in d:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: colorama in d:\users\user\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.3.1->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in d:\users\user\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow) (2.40.3)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in d:\users\user\anaconda3\lib\site-packages (from fastapi<1->mlflow-skinny==3.3.1->mlflow) (0.47.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\users\user\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.1->mlflow) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in d:\users\user\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.1->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\user\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask<4->mlflow) (2.1.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in d:\users\user\anaconda3\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.1->mlflow) (0.57b0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.1->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.1->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in d:\users\user\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: h11>=0.8 in d:\users\user\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.3.1->mlflow) (0.14.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in d:\users\user\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.1->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\user\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\user\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\users\user\anaconda3\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.1->mlflow) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in d:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.1->mlflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow) (0.4.8)

# %%
import os
os.environ["METAFLOW_DEFAULT_STEP_DECORATORS"] = "[]"
os.environ["METAFLOW_DEFAULT_METADATA"] = "local"

# %%
import mlflow
import metaflow
print("MLflow version:", mlflow.__version__)
print("Metaflow version:", metaflow.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\extension_support\plugins.py:99, in get_plugin(category, class_path, name)
#      98 try:
# ---> 99     plugin_module = importlib.import_module(path)
#     100 except ImportError as e:
#
# File D:\Users\User\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\plugins\aws\batch\batch_decorator.py:20
#      19 from metaflow.plugins.timeout_decorator import get_run_time_limit_for_task
# ---> 20 from metaflow.sidecar import Sidecar
#      21 from metaflow.unbounded_foreach import UBF_CONTROL
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\sidecar\__init__.py:1
# ----> 1 from .sidecar import Sidecar
#       2 from .sidecar_messages import MessageTypes, Message
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\sidecar\sidecar.py:1
# ----> 1 from .sidecar_subprocess import SidecarSubProcess
#       4 class Sidecar(object):
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\sidecar\sidecar_subprocess.py:4
#       3 import subprocess
# ----> 4 import fcntl
#       5 import select
#
# ModuleNotFoundError: No module named 'fcntl'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 import mlflow
# ----> 2 import metaflow
#       3 print("MLflow version:", mlflow.__version__)
#       4 print("Metaflow version:", metaflow.__version__)
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\__init__.py:120
#     115 # data layer
#     116 # For historical reasons, we make metaflow.plugins.datatools accessible as
#     117 # metaflow.datatools. S3 is also a tool that has historically been available at the
#     118 # top-level so keep as is.
#     119 lazy_load_aliases({"metaflow.datatools": "metaflow.plugins.datatools"})
# --> 120 from .plugins.datatools import S3
#     122 # includefile
#     123 from .includefile import IncludeFile
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\plugins\__init__.py:197
#     193 def get_runner_cli_path():
#     194     return resolve_plugins("runner_cli", path_only=True)
# --> 197 STEP_DECORATORS = resolve_plugins("step_decorator")
#     198 FLOW_DECORATORS = resolve_plugins("flow_decorator")
#     199 ENVIRONMENTS = resolve_plugins("environment")
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\extension_support\plugins.py:164, in resolve_plugins(category, path_only)
#     162 else:
#     163     if name_extractor is not None:
# --> 164         to_return.append(get_plugin(category, class_path, name))
#     165     else:
#     166         to_return[name] = get_plugin(category, class_path, name)
#
# File D:\Users\User\anaconda3\Lib\site-packages\metaflow\extension_support\plugins.py:101, in get_plugin(category, class_path, name)
#      99     plugin_module = importlib.import_module(path)
#     100 except ImportError as e:
# --> 101     raise ValueError(
#     102         "Cannot locate %s plugin '%s' at '%s'" % (category, name, path)
#     103     ) from e
#     104 cls = getattr(plugin_module, cls_name, None)
#     105 if cls is None:
#
# ValueError: Cannot locate step_decorator plugin 'batch' at 'metaflow.plugins.aws.batch.batch_decorator'

# %%
from src import train
from importlib import reload
reload(train)

model = train.train_model()
model
# Out:
# 2025/08/24 21:10:59 INFO mlflow.tracking.fluent: Experiment with name 'Collision_Prediction' does not exist. Creating a new experiment.
# 2025/08/24 21:11:01 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/08/24 21:11:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model trained with MSE: 0.17528229023004277, R2: 0.8914582620268914
# RandomForestRegressor(max_depth=10, n_estimators=200, random_state=42)

# %% [markdown]
# ## 4) Orquestación completa con Metaflow (`flows/collision_flow.py`)
#
# Para ejecutar el **pipeline completo** desde la terminal, ubicándote en la carpeta base del proyecto:
#
# ```bash
# python flows/collision_flow.py run
# ```
#
# > Si preferís lanzarlo desde aquí, podés descomentar la celda siguiente.

# %%
#OPCIONAL: ejecutar flujo desde notebook (requiere internet para ingesta)
import subprocess, shlex
cmd = "python flows/collision_flow.py run"
print("Ejecutando:", cmd)
subprocess.run(shlex.split(cmd), cwd=str(BASE))
print("Listo para ejecutar el flujo desde terminal.")
# Out:
# Ejecutando: python flows/collision_flow.py run
# Listo para ejecutar el flujo desde terminal.

# %%
import os
print(os.getcwd())  # ruta actual
# Out:
# C:\Users\User\CEIA\MLOps

# %% [markdown]
# ### 5) UI de MLflow local
#
# Abrí la interfaz de MLflow para inspeccionar corridas, métricas y artefactos:
#
# ```bash
# mlflow ui --backend-store-uri mlruns/
# ```
# y luego navegá a `http://localhost:5000`.
